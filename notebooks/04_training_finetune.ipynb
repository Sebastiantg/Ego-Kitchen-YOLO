# %% [markdown]
# # 04 — Entrenamiento Fine-Tuning YOLOv8
# Entrenamiento con 100 épocas, early stopping (patience=10) e imágenes de 640px.

# %% [raw]
# yolo detect train data=./data/epic_train_subset/dataset.yaml model=yolov8s.pt epochs=100 patience=10 imgsz=640 name=epic_full_epoch

# %% [markdown]
# Los pesos se guardarán en:
# 📁 runs/detect/epic_full_epoch/weights/
# Incluye:
# - `best.pt`: mejor rendimiento mAP
# - `last.pt`: última iteración
